# %%
#python is high level language
print("hello meena")
# Out:
# hello meena

# %%
print("A","B",sep="*")
# Out:
# A*B

# %%
print("hello meena",sep="_",end=" thank you ")
print("hi")
# Out:
# hello meena thank you hi

# %%
name="meena"
age=20
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
print(f"my name is {name}")
# Out:
# my name is meena

# %%
choice=int(input("enter the your choice"))
deposit=int(input("enter the deposit"))
withdraw=int(input("enter the withdraw amt"))

if(choice==1):
    if(deposit>withdraw):
       print("withdraw can be done")
    else:
        print("cant be withdrawn")
elif(choice==2):
    print(f"Enter the deposit amt{deposit}")
    if(deposit>withdraw):
        print("withdrawn")
    else:
        print("cant withdraw")
elif(choice==3):
    print(f"display balance{deposit-withdraw}")
else:
    print("Invalid choice")
# Out:
# enter the your choice 3
# enter the deposit 3000
# enter the withdraw amt 2000
# display balance1000

# %%
for i in range(3):
    for j in range(i+1):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *

# %%
for i in range(0,3):
    for j in range(i+1):
        print(j+1,end="")
    print()
# Out:
# 1
# 12
# 123

# %%
for i in range(7):
    for j in range(0,7,1):
        if i==0 or i==6 or j==0 or j==6:
           print("*",end=" ")
        else:
            print(" ",end=" ")
    print(" ")
# Out:
# * * * * * * *
# *           *
# *           *
# *           *
# *           *
# *           *
# * * * * * * *

# %%
for i in range(3):
    for j in range(0,3,1):
        if i==j :
           print("*",end=" ")
        elif i==2 and j==0 or i==0 and j==2 :
            print("*", end=" ")
        else:
            print(" ",end=" ")
    print(" ")
# Out:
# *   *
#   *
# *   *

# %%
for i in range(3):
    num = 65
    for j in range(i+1):
        print(chr(num), end=" ")
        num+=1
    print()
# Out:
# A
# A B
# A B C

# %%
for i in range(5):
    for j in range(7):
        if (i==1)or(i==0 and j%3!=0)or (i==2 and( j!=6 and j!=0)) or (i==3 and (j==2 or j==3 or j==4)) or (i==4 and j==3) :
           print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
#   * *   * *
# * * * * * * *
#   * * * * *
#     * * *
#       *

# %%
user="meena"
user[0:1]
# Out:
# 'm'

# %%
user=input("enter a string")
user1=user[::-1]
if user==user1:
    print("yes")
else:
    print("no")
# Out:
# enter a string 343
# yes

# %%
user="india is a country "
user.title()
# Out:
# 'India Is A Country '

# %%
user1="india"
user1.count("i")
# Out:
# 2

# %%
a="malayalam"
for i in a:
    for j in a:
        st = ""
        st += j
        if i==j:
          continue
print(st)
# Out:
# m

# %%
user="india"
user[::-1]
# Out:
# 'aidni'

# %%
list1 = ["a","e","i","o","u"]
n = input("Enter a strng:").lower()
count = 0 
for x in n:
    if x in list1:
        count+=1
    print(x)
print("count:",count, end=" ")
# Out:
# Enter a strng: MEE
# m
# e
# e
# count: 2

# %%
def count(string):
    return{x:string.count(x) for x in string}
count("meena")
# Out:
# {'m': 1, 'e': 2, 'n': 1, 'a': 1}

# %%
n=input("enter a password")
fif = n[4]
if len(n)<6:
    print("Invalid")
if (fif.isdigit() and 1<=int(fif)<=5):
    print("valid")
else:
    print("invalid")
# Out:
# enter a password sfsh437
# valid

# %%
for i in range(7):
    for j in range(7):   
        if (i==3)or(j==3)or (i==j) or (i+j==6):
           print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# *     *     *
#   *   *   *
#     * * *
# * * * * * * *
#     * * *
#   *   *   *
# *     *     *

# %%
for i in range(5):
    for j in range(5):   
        if (j==2 and i==0)  or (i==2 and j==2 ) or (i==4 and j==2) or (i==1 and j==1) or (i==3 and j==3) or (i==1 and j==3) or (i==3 and j==1) :
           print("-",end=" ")
        elif(i==1 and (j==0 or j==4)) or (i==3 and (j==0 or j==4)):
            print(" ",end=" ")
        else:
            print("*",end=" ")
    print()
# Out:
# * * - * *
#   - * -
# * * - * *
#   - * -
# * * - * *

# %%
a= int(input("enter the number"))
# Out:
# enter the number 12

# %%
b=float(input("enter the number"))
# Out:
# enter the number 12.4

# %%
a,b=map (int,input("enter a number").split())
print(a+b)
# Out:
# enter a number 12 23
# 35

# %%
a,b=map (float,input("enter a number").split())
print(a+b)
# Out:
# enter a number 12.2 13.2
# 25.4

# %%
a,b=map(float,input("enter a number").split())
print(a+b)
# Out:
# enter a number 12.3 34.5
# 46.8

# %%
import random
nums=random.randint(1,10)
guess=None
while(nums!=guess):
    guess=int(input("enter a number"))
    if(guess>nums):
        print("the number is greater, reduce the number")
    elif(guess<nums):
        print("the number is lesser, increase the number")
    else:
        print("yes u guess it right")              
print()
# Out:
# enter a number 12
# the number is greater, reduce the number
# enter a number 2
# the number is lesser, increase the number
# enter a number 3
# the number is lesser, increase the number
# enter a number 4
# the number is lesser, increase the number
# enter a number 1
# the number is lesser, increase the number
# enter a number 2
# the number is lesser, increase the number
# enter a number 2
# the number is lesser, increase the number
# enter a number 5
# the number is lesser, increase the number
# enter a number 6
# yes u guess it right

# %%
nums=list(map(int,input("enter a numbers").split()))
nums
# Out:
# enter a numbers 12 13 14
# [12, 13, 14]

# %% [raw]
# nums=input("enter the number").split(',')
# nums

# %%
nums=input("enter the number").split(',')
nums
# Out:
# enter the number a,f,g
# ['a', 'f', 'g']

# %%
x=eval('10+20')
x
# Out:
# 30

# %%
name=input("enter a word")
if(name=='admin'):
    print("yes")
else:
    print("not true")
# Out:
# enter a word admin
# yes

# %%
a="      hello"
a.lstrip()
# Out:
# 'hello'

# %%
a="hello      "
a.rstrip()
# Out:
# 'hello'

# %%
s=input("enter the number").lower()
print(s)
# Out:
# enter the number MD
# md

# %%
s=input('enter a string')
s.isalpha()
s.isnumeric()
s.isalnum()
# Out:
# enter a string hdeheh337
# True
